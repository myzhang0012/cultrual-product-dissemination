# %%
# !pip install fake_useragent

# %%
# 把要爬的视频记录在这里
# 有26个单独的投稿视频，13个被归作为综艺的平台视频，总共39个视频

# 以下代码目前应该只适用于单独的投稿视频
# 被归为综艺的平台视频的url规律需要重新找？（万一他不是简单的bv转av号呢？（以防万一（还是看一下吧

# 单独的投稿视频链接
1、https://www.bilibili.com/video/BV1gU4y157ib/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
2、https://www.bilibili.com/video/BV1nU4y1579w/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
3、https://www.bilibili.com/video/BV1Z5411M7vA/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
4、https://www.bilibili.com/video/BV1ph411a7Zt/?spm_id_from=333.337.search-card.all.click
    206083392 ok
5、https://www.bilibili.com/video/BV1wo4y1y7Bn/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    376010141 ok
6、https://www.bilibili.com/video/BV1Zw411Z7Sy/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    333601296 ok
7、https://www.bilibili.com/video/BV1HK4y197Fn/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    931109171 ok
8、https://www.bilibili.com/video/BV18w411Z7ZY/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    333510943 ok
9、https://www.bilibili.com/video/BV1GU4y157yn/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    673559513 ok
10、https://www.bilibili.com/video/BV1hh411e7fJ/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    206011366 ok
11、https://www.bilibili.com/video/BV1go4y1y7D8/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    376039932 ok
12、https://www.bilibili.com/video/BV15K4y197P3/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    931083792 ok
    
    
13、https://www.bilibili.com/video/BV1cU4y157SU/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    673522536 ok
14、https://www.bilibili.com/video/BV1KU4y157PH/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    673573774 ok
15、https://www.bilibili.com/video/BV1vg411G7UH/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    503518168 ok
16、https://www.bilibili.com/video/BV19w411Z761/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    333556969 ok
17、https://www.bilibili.com/video/BV1t54y1G7dd/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    846122885 ok
18、https://www.bilibili.com/video/BV1644y167SC/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    973591109 ok
19、https://www.bilibili.com/video/BV13v411p7Q1/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    248544327 ok
20、https://www.bilibili.com/video/BV19w411Z7V9/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    333551245 ok
21、https://www.bilibili.com/video/BV1kq4y157Ur/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    546062777 ok
22、https://www.bilibili.com/video/BV1Hg411G7Yo/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    503512112 ok


23、https://www.bilibili.com/video/BV1no4y1y7NF/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    376066721 ok
24、https://www.bilibili.com/video/BV1k64y1R7My/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    758541068 ok
25、https://www.bilibili.com/video/BV1ow411Z7zu/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    333597594 ok
26、https://www.bilibili.com/video/BV1FK4y197em/?spm_id_from=333.337.search-card.all.click&vd_source=76e86f559b2b519718e1d44f7dd42851
    931038547 ok
    
    


# 被归为综艺的视频
27、https://api.bilibili.com/x/v2/reply/main?callback=jQuery17209318675367160576_1671004835267&jsonp=jsonp&next=3&type=1&oid=803617634&mode=3&plat=1&_=1671004851105
ok

28、https://api.bilibili.com/x/v2/reply/main?callback=jQuery172007004686241397606_1671005018610&jsonp=jsonp&next=0&type=1&oid=c&mode=3&plat=1&_=1671005022166
ok

29、https://api.bilibili.com/x/v2/reply/main?callback=jQuery17206059429773245282_1671005064399&jsonp=jsonp&next=0&type=1&oid=291072780&mode=3&plat=1&_=1671005068165
ok
30、https://api.bilibili.com/x/v2/reply/main?callback=jQuery1720894906850582885_1671005109187&jsonp=jsonp&next=0&type=1&oid=673570234&mode=3&plat=1&_=1671005112452
ok
31、https://api.bilibili.com/x/v2/reply/main?callback=jQuery17203311695824012826_1671005169161&jsonp=jsonp&next=0&type=1&oid=291038699&mode=3&plat=1&_=1671005171415
ok
32、https://api.bilibili.com/x/v2/reply/main?callback=jQuery172016833348873443388_1671005213866&jsonp=jsonp&next=0&type=1&oid=248570029&mode=3&plat=1&_=1671005223182
ok
33、https://api.bilibili.com/x/v2/reply/main?callback=jQuery172025995697059982215_1671005262885&jsonp=jsonp&next=0&type=1&oid=248552757&mode=3&plat=1&_=1671005265763
ok
34、https://api.bilibili.com/x/v2/reply/main?callback=jQuery172016297626387529696_1671005312621&jsonp=jsonp&next=0&type=1&oid=631124199&mode=3&plat=1&_=1671005317159
ok
35、https://api.bilibili.com/x/v2/reply/main?callback=jQuery17206267532642550799_1671014927631&jsonp=jsonp&next=0&type=1&oid=546004407&mode=3&plat=1&_=1671014928973
ok
36、https://api.bilibili.com/x/v2/reply/main?callback=jQuery17208876965717308485_1671014967952&jsonp=jsonp&next=0&type=1&oid=803593340&mode=3&plat=1&_=1671014970089
ok
37、https://api.bilibili.com/x/v2/reply/main?callback=jQuery172038668902582930564_1671015007647&jsonp=jsonp&next=0&type=1&oid=376051393&mode=3&plat=1&_=1671015010280
ok
38、https://api.bilibili.com/x/v2/reply/main?callback=jQuery17204988251496451117_1671015040627&jsonp=jsonp&next=0&type=1&oid=291092798&mode=3&plat=1&_=1671015042528
ok
39、https://api.bilibili.com/x/v2/reply/main?callback=jQuery17204988251496451117_1671015040629&jsonp=jsonp&next=0&type=1&oid=973556854&mode=3&plat=1&_=1671015079534

# %%
# bv转av号
import math
def BvToAv(Bv):
    # 1.去除Bv号前的"Bv"字符
    BvNo1 = Bv[2:]
    keys = {
        '1': '13', '2': '12', '3': '46', '4': '31', '5': '43', '6': '18', '7': '40', '8': '28', '9': '5',
        'A': '54', 'B': '20', 'C': '15', 'D': '8', 'E': '39', 'F': '57', 'G': '45', 'H': '36', 'J': '38', 'K': '51',
        'L': '42', 'M': '49', 'N': '52', 'P': '53', 'Q': '7', 'R': '4', 'S': '9', 'T': '50', 'U': '10', 'V': '44',
        'W': '34', 'X': '6', 'Y': '25', 'Z': '1',
        'a': '26', 'b': '29', 'c': '56', 'd': '3', 'e': '24', 'f': '0', 'g': '47', 'h': '27', 'i': '22', 'j': '41',
        'k': '16', 'm': '11', 'n': '37', 'o': '2',
        'p': '35', 'q': '21', 'r': '17', 's': '33', 't': '30', 'u': '48', 'v': '23', 'w': '55', 'x': '32', 'y': '14',
        'z': '19'

    }
    # 2. 将key对应的value存入一个列表
    BvNo2 = []
    for index, ch in enumerate(BvNo1):
        BvNo2.append(int(str(keys[ch])))

    # 3. 对列表中不同位置的数进行*58的x次方的操作

    BvNo2[0] = int(BvNo2[0] * math.pow(58, 6));
    BvNo2[1] = int(BvNo2[1] * math.pow(58, 2));
    BvNo2[2] = int(BvNo2[2] * math.pow(58, 4));
    BvNo2[3] = int(BvNo2[3] * math.pow(58, 8));
    BvNo2[4] = int(BvNo2[4] * math.pow(58, 5));
    BvNo2[5] = int(BvNo2[5] * math.pow(58, 9));
    BvNo2[6] = int(BvNo2[6] * math.pow(58, 3));
    BvNo2[7] = int(BvNo2[7] * math.pow(58, 7));
    BvNo2[8] = int(BvNo2[8] * math.pow(58, 1));
    BvNo2[9] = int(BvNo2[9] * math.pow(58, 0));

    # 4.求出这10个数的合
    sum = 0
    for i in BvNo2:
        sum += i
    # 5. 将和减去100618342136696320
    sum -= 100618342136696320
    # 6. 将sum 与177451812进行异或
    temp = 177451812

    return sum ^ temp


if __name__ == '__main__':
    Bv = input("请输入Bv号:")
    print(Bv + "的Av号为:av" + str(BvToAv(Bv)))
    print("链接地址为：http://www.bilibili.com/video/av" + str(BvToAv(Bv)))
# Out:
# 请输入Bv号:V1HK4y197Fn
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [43], in <cell line: 47>()
#      47 if __name__ == '__main__':
#      48     Bv = input("请输入Bv号:")
# ---> 49     print(Bv + "的Av号为:av" + str(BvToAv(Bv)))
#      50     print("链接地址为：http://www.bilibili.com/video/av" + str(BvToAv(Bv)))
#
# Input In [43], in BvToAv(Bv)
#      31 BvNo2[7] = int(BvNo2[7] * math.pow(58, 7));
#      32 BvNo2[8] = int(BvNo2[8] * math.pow(58, 1));
# ---> 33 BvNo2[9] = int(BvNo2[9] * math.pow(58, 0));
#      35 # 4.求出这10个数的合
#      36 sum = 0
#
# IndexError: list index out of range

# %%
# 设置一些可用的代理ip
# 随机选择一个ip

# 根据这篇博客（https://www.cnblogs.com/chenlove/p/15148282.html）
# 到这个网站https://h.shenlongip.com/index/index.html免费获取了1000ip


# 先把装了2000个代理ip地址的xlxs文件转成“字典为元素”的列表
import pandas as pd

# ipdict = {}
ipdata = pd.read_excel(r'/Users/my/Desktop/代理ip的地址.xlsx')
ipdata.fillna("",inplace = True)

proxieslist = []

for i in ipdata.index.values:
    line = ipdata.loc[i,['http']].to_dict()
    proxieslist.append(line)
print(proxieslist)
# Out:
# [{'http': '117.86.24.246:40035'}, {'http': '49.87.253.109:40014'}, {'http': '116.168.32.194:40015'}, {'http': '114.234.129.131:40023'}, {'http': '36.6.142.66:40030'}, {'http': '123.244.152.176:40009'}, {'http': '183.158.89.74:40007'}, {'http': '121.205.223.78:40012'}, {'http': '119.115.15.66:40008'}, {'http': '113.242.171.100:40045'}, {'http': '42.5.104.157:40017'}, {'http': '117.86.138.175:40029'}, {'http': '42.177.51.30:40004'}, {'http': '112.66.244.66:40009'}, {'http': '114.224.223.129:40034'}, {'http': '180.122.11.160:40037'}, {'http': '113.141.222.193:40036'}, {'http': '114.219.43.248:40029'}, {'http': '49.84.44.99:40017'}, {'http': '115.192.77.71:40039'}, {'http': '114.216.144.209:40018'}, {'http': '180.120.138.200:40035'}, {'http': '183.150.51.67:40046'}, {'http': '106.110.193.199:40025'}, {'http': '117.86.138.241:40027'}, {'http': '58.63.37.138:40021'}, {'http': '140.250.145.49:40036'}, {'http': '123.96.177.112:40039'}, {'http': '117.34.231.164:40023'}, {'http': '121.233.26.5
# ...

# %%
# 定义随机的useragent
from fake_useragent import UserAgent
ua = UserAgent()
print(ua.random)
# Out:
# Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/13.0.782.107 Safari/535.1

# %%
import requests
import time
from bs4 import BeautifulSoup
import json
import csv
import pandas as pd
import random
import telnetlib


# 首先我们写好抓取网页的函数

def get_html(url):
    headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'user-agent': ua.random
        # 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',
        # 'user-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:6.0) Gecko/20100101 Firefox/6.0', 
    }  # 爬虫模拟访问信息

    # 测试代理是否能用
#     for try1try in range(10): # 试十次
#         randomip = random.choice(proxieslist)
#         try:
#             tn = telnetlib.Telnet(randomip, port='9999', timeout=15)
#             break
#         except:
#             print("change ip")
#             randomip = random.choice(proxieslist)
    
    randomip = random.choice(proxieslist)
    print(randomip)
    
    r = requests.get(url, timeout=15, headers=headers, proxies=randomip)
    r.raise_for_status()
    r.endcodding = 'utf-8'
    # print(r.text)
    return r.text


# 获得子评论
def get_replycomments(root):
    e2 = 0
    replypage = 1  # 定义一个子评论的页数
    replycomments = []
    while e2 == 0:
        print("子评论开始翻页～～～～～～～～～～～～～～～～～～～")
        url2 = f'https://api.bilibili.com/x/v2/reply/reply?jsonp=jsonp&pn={replypage}&type=1&oid=758541068&ps=10&root={root}&_=1647581648753'

        try:
            # comments = []
            html2 = get_html(url2)
            try:
                s2 = json.loads(html2)
            except:
                print("jsonload error")

            num2 = len(s2['data']['replies'])  # 获取每页子评论的栏数 # 具体的字段观察实际的json文件 # 其实和根评论没啥区别
            print(num2)
            j = 0
            while j < num2:
                print("子评论的每一栏-----------------------------------------end")
                replycomment = s2['data']['replies'][j]  # 获取每栏子评论

                InfoDict2 = {}  # 存储每组信息字典（子评论）
                
                InfoDict2['root'] = replycomment['root']  # 发表根评论的用户的唯一标识id
                
                InfoDict2['uid'] = replycomment['member']['mid']  # 发表子评论的用户的唯一标识id
                InfoDict2['uname'] = replycomment['member']['uname']  # 发表子评论的用户名
                InfoDict2['usex'] = replycomment['member']['sex']  # 发表子评论的用户的性别
                InfoDict2['ulevel'] = replycomment['member']['level_info']['current_level']  # 发表子评论的用户的等级

                InfoDict2['rpid'] = replycomment['rpid']  # 子评论的唯一标识
                InfoDict2['like'] = replycomment['like']  # 子评论的点赞数量
                InfoDict2['time'] = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(replycomment['ctime']))  # 发表子评论的时间
                InfoDict2['content'] = replycomment['content']['message']  # 子评论内容
                
                print(InfoDict2)
                
                replycomments.append(InfoDict2)

                j = j + 1

            replypage = replypage + 1
            if replypage % 3 == 0:
                time.sleep(2)
        except:
            e2 = 1
    return replycomments


# 获得根评论
def get_comments(url, comments):
    '''
    分析网页文件，整理信息，保存在列表变量中
    '''
    print("啊好烦呐测试1")
    
    # 首先，我们把需要爬取信息的网页下载到本地
    html = get_html(url)
    try:
        s = json.loads(html)
    except:
        print("jsonload error")
        

    num = len(s['data']['replies'])  # 获取每页评论栏的数量
    print(num)
    
    if num == 0:
        comments = []
        return comments
    
    print("啊啊啊测试")

    i = 0
    while i < num:
        print("开始根评论的新一栏｜｜｜｜｜｜｜")
        comment = s['data']['replies'][i]  # 获取每栏评论

        InfoDict = {}  # 存储每组信息字典
        
        InfoDict['root'] = comment['root']  # 发表根评论的用户的唯一标识id
        
        InfoDict['uid'] = comment['member']['mid']  # 发表根评论的用户的唯一标识id
        InfoDict['uname'] = comment['member']['uname']  # 发表根评论的用户名
        InfoDict['usex'] = comment['member']['sex']  # 发表根评论的用户的性别
        InfoDict['ulevel'] = comment['member']['level_info']['current_level']  # 发表根评论的用户的等级
        
        InfoDict['rpid'] = comment['rpid']  # 根评论的唯一标识
        InfoDict['like'] = comment['like']  # 根评论的点赞数量
        InfoDict['time'] = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(comment['ctime']))  # 发表根评论的时间
        InfoDict['content'] = comment['content']['message']  # 根评论内容
        print(InfoDict)
        comments.append(InfoDict)
        # print(comments)
        if InfoDict['uid'] is not None:
            print("进入子评论>>>>>>>>>>>>>>>>>>>>>")
            comments.extend(get_replycomments(InfoDict['rpid']))

        i = i + 1
        print(i,num)
        
    return comments

# 网上的保存方式太复杂了……自己改了一下
def Out2File(df):
    '''
    将爬取到的文件写入到本地
    保存到当前目录的 BiliBiliComments.csv文件中。
    '''
    df.to_csv("BiliBiliComments24.csv")
    
    print('全部保存完成')

#     with open('BiliBiliComments.csv', 'a+', encoding='utf-8') as f:
#         m = 0
#         for eachcomment in dict:
#             m = m + 1
#             try:
#                 f.write('姓名：{}\t  点赞数：{}\t \n 评论内容：{}\t   \n '.format(
#                     eachcomment['uname'], eachcomment['like'], eachcomment['content']))
#                 f.write("-----------------\n")
#             except:
#                 print("out2File error")

#     headernames = ['uid', 'uname', 'usex', 'ulevel', 'rpid', 'like', 'time', 'content']
#     with open('test.csv', 'a', newline='', encoding='utf-8') as f:
#         writer = csv.DictWriter(f, fieldnames=headernames)
#         writer.writeheader()
#         writer.writerows(dict)    




if __name__ == '__main__':
    global e
    e = 0
    page = 1  # 这个是根评论的页数
    totalcomments = []
    eachpagecomments = []
    while e == 0:
        print("开始根评论的新一页！！！")
        
        url1 = f'https://api.bilibili.com/x/v2/reply/main?jsonp=jsonp&next={page}&type=1&oid=758541068&mode=3&plat=1&_=1647577851745'
        try:
            eachpagecomments = get_comments(url1, eachpagecomments)
            if eachpagecomments == []:
                break
            # print(eachpagecomments)
            totalcomments.extend(eachpagecomments)
            # print(totalcomments)
            print("page:", page)
            page = page + 1
            # 为了降低被封ip的风险，每爬3页便随机歇3秒。
            if page % 2 == 0:
                time.sleep(2)
            eachpagecomments = []
            # print("e=", e)
        except:
            e = 1
    # print(totalcomments)
    df_totalcomments = pd.DataFrame.from_dict(totalcomments)
    print(df_totalcomments)
    Out2File(df_totalcomments)
# Out:
# 开始根评论的新一页！！！
# 啊好烦呐测试1
# {'http': '114.233.70.97:40047'}
# 12
# 啊啊啊测试
# 开始根评论的新一栏｜｜｜｜｜｜｜
# {'root': 0, 'uid': '100935631', 'uname': '欧呀嘿鸭哟', 'usex': '保密', 'ulevel': 5, 'rpid': 4724684780, 'like': 15, 'time': '2021-06-14 09:52:01', 'content': 'Up，记得申请小闪电嘞，顺说一声，首页通知书[歪嘴][歪嘴]'}
# 进入子评论>>>>>>>>>>>>>>>>>>>>>
# 子评论开始翻页～～～～～～～～～～～～～～～～～～～
# {'http': '49.84.124.243:40019'}
# 3
# 子评论的每一栏-----------------------------------------end
# {'root': 4724684780, 'uid': '1963716390', 'uname': '河南经济广播', 'usex': '保密', 'ulevel': 6, 'rpid': 4726171379, 'like': 1, 'time': '2021-06-14 14:12:03', 'content': '借您吉言'}
# 子评论的每一栏-----------------------------------------end
# {'root': 4724684780, 'uid': '100935631', 'uname': '欧呀嘿鸭哟', 'usex': '保密', 'ulevel': 5, 'rpid': 4726183490, 'like': 0, 'time': '2021-06-14 14:14:55', 'content': '回复 @河南经济广播 :hiahiahia有小闪电⚡了[星星眼]'}
# 子评论的每一栏-----------------------------------------end
# ...

# %%
# df_totalcomments.to_csv("BiliBiliComments.csv")
